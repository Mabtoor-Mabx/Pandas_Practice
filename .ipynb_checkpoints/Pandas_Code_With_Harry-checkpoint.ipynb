# %% [markdown]
# # Pandas_Code_With_Harry

# %%
import numpy as np
import pandas as pd

# %%
diction = {
    'train no' :[21,41,41,14,45,4,54,5,435,31,41,5,23426,44,3,5523,3245],
    'Seat No' : [3,2,45,7,4,2,6,3,73,6,8,5,3,6,87,4,56],
    'Passangers No' :[6,3,2,5,7,3,6,8,4,2,6,8,4,2,5,87,4],
    'ASM NO' : [6,3,1,4,7,8,5,4,3,5,7,5,3,6,8,5,3]
}

# %%
diction
# Out:
# {'train no': [21,
#   41,
#   41,
#   14,
#   45,
#   4,
#   54,
#   5,
#   435,
#   31,
#   41,
#   5,
#   23426,
#   44,
#   3,
#   5523,
#   3245],
#  'Seat No': [3, 2, 45, 7, 4, 2, 6, 3, 73, 6, 8, 5, 3, 6, 87, 4, 56],
#  'Passangers No': [6, 3, 2, 5, 7, 3, 6, 8, 4, 2, 6, 8, 4, 2, 5, 87, 4],
#  'ASM NO': [6, 3, 1, 4, 7, 8, 5, 4, 3, 5, 7, 5, 3, 6, 8, 5, 3]}

# %%
df = pd.DataFrame(diction)

# %%
df
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 0         21        3              6       6
# 1         41        2              3       3
# 2         41       45              2       1
# 3         14        7              5       4
# 4         45        4              7       7
# 5          4        2              3       8
# 6         54        6              6       5
# 7          5        3              8       4
# 8        435       73              4       3
# 9         31        6              2       5
# 10        41        8              6       7
# 11         5        5              8       5
# 12     23426        3              4       3
# 13        44        6              2       6
# 14         3       87              5       8
# 15      5523        4             87       5
# 16      3245       56              4       3

# %%
df.head()
# Out:
#    train no  Seat No  Passangers No  ASM NO
# 0        21        3              6       6
# 1        41        2              3       3
# 2        41       45              2       1
# 3        14        7              5       4
# 4        45        4              7       7

# %%
df.tail()
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 12     23426        3              4       3
# 13        44        6              2       6
# 14         3       87              5       8
# 15      5523        4             87       5
# 16      3245       56              4       3

# %%
df.head(2)
# Out:
#    train no  Seat No  Passangers No  ASM NO
# 0        21        3              6       6
# 1        41        2              3       3

# %%
df.tail(3)
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 14         3       87              5       8
# 15      5523        4             87       5
# 16      3245       56              4       3

# %%
df.to_csv('Train_info.csv')

# %%
df.to_csv('Train_Info_Without_indices.csv', index=False)

# %%
df.describe()
# Out:
#            train no    Seat No  Passangers No     ASM NO
# count     17.000000  17.000000      17.000000  17.000000
# mean    1939.882353  18.823529       9.529412   4.882353
# std     5733.892699  27.780918      20.059654   1.964763
# min        3.000000   2.000000       2.000000   1.000000
# 25%       14.000000   3.000000       3.000000   3.000000
# 50%       41.000000   6.000000       5.000000   5.000000
# 75%       54.000000   8.000000       6.000000   6.000000
# max    23426.000000  87.000000      87.000000   8.000000

# %%
pd.read_csv('Train_Info_Without_indices.csv')
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 0         21        3              6       6
# 1         41        2              3       3
# 2         41       45              2       1
# 3         14        7              5       4
# 4         45        4              7       7
# 5          4        2              3       8
# 6         54        6              6       5
# 7          5        3              8       4
# 8        435       73              4       3
# 9         31        6              2       5
# 10        41        8              6       7
# 11         5        5              8       5
# 12     23426        3              4       3
# 13        44        6              2       6
# 14         3       87              5       8
# 15      5523        4             87       5
# 16      3245       56              4       3

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
df.columns
# Out:
# Index(['train no', 'Seat No', 'Passangers No', 'ASM NO'], dtype='object')

# %%
df['train no']
# Out:
# 0        21
# 1        41
# 2        41
# 3        14
# 4        45
# 5         4
# 6        54
# 7         5
# 8       435
# 9        31
# 10       41
# 11        5
# 12    23426
# 13       44
# 14        3
# 15     5523
# 16     3245
# Name: train no, dtype: int64

# %%
df['train no'][0]
# Out:
# 21

# %%
df['train no'][0] = 43

# %%
df
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 0         43        3              6       6
# 1         41        2              3       3
# 2         41       45              2       1
# 3         14        7              5       4
# 4         45        4              7       7
# 5          4        2              3       8
# 6         54        6              6       5
# 7          5        3              8       4
# 8        435       73              4       3
# 9         31        6              2       5
# 10        41        8              6       7
# 11         5        5              8       5
# 12     23426        3              4       3
# 13        44        6              2       6
# 14         3       87              5       8
# 15      5523        4             87       5
# 16      3245       56              4       3

# %%
df.head(2)
# Out:
#    train no  Seat No  Passangers No  ASM NO
# 0        43        3              6       6
# 1        41        2              3       3

# %%
df.tail(2)
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 15      5523        4             87       5
# 16      3245       56              4       3

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
df.columns
# Out:
# Index(['train no', 'Seat No', 'Passangers No', 'ASM NO'], dtype='object')

# %%
df.describe()
# Out:
#            train no    Seat No  Passangers No     ASM NO
# count     17.000000  17.000000      17.000000  17.000000
# mean    1941.176471  18.823529       9.529412   4.882353
# std     5733.435011  27.780918      20.059654   1.964763
# min        3.000000   2.000000       2.000000   1.000000
# 25%       14.000000   3.000000       3.000000   3.000000
# 50%       41.000000   6.000000       5.000000   5.000000
# 75%       54.000000   8.000000       6.000000   6.000000
# max    23426.000000  87.000000      87.000000   8.000000

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17, step=1)

# %%
ser = pd.Series(np.random.randint(2,4))

# %%
ser
# Out:
# 0    3
# dtype: int64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(443,4), index=np.arange(443))

# %%
newdf
# Out:
#             0         1         2         3
# 0    0.777676  0.647571  0.655263  0.572103
# 1    0.264215  0.192503  0.858678  0.960484
# 2    0.271655  0.187802  0.639838  0.211768
# 3    0.074240  0.575926  0.371847  0.447757
# 4    0.149245  0.319579  0.902926  0.291430
# ..        ...       ...       ...       ...
# 438  0.611236  0.868276  0.475830  0.496859
# 439  0.470998  0.714874  0.812492  0.316903
# 440  0.706543  0.318493  0.038463  0.883714
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633
#
# [443 rows x 4 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3
# 0  0.777676  0.647571  0.655263  0.572103
# 1  0.264215  0.192503  0.858678  0.960484
# 2  0.271655  0.187802  0.639838  0.211768
# 3  0.074240  0.575926  0.371847  0.447757
# 4  0.149245  0.319579  0.902926  0.291430

# %%
newdf.head(2)
# Out:
#           0         1         2         3
# 0  0.777676  0.647571  0.655263  0.572103
# 1  0.264215  0.192503  0.858678  0.960484

# %%
newdf.tail(2)
# Out:
#             0         1         2         3
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633

# %%
newdf.describe()
# Out:
#                 0           1           2           3
# %%
newdf.sort_index(axis=0, ascending=False)
# Out:
#             0         1         2         3
# 442  0.296793  0.015466  0.009774  0.085633
# 441  0.242174  0.822804  0.357553  0.382375
# 440  0.706543  0.318493  0.038463  0.883714
# 439  0.470998  0.714874  0.812492  0.316903
# 438  0.611236  0.868276  0.475830  0.496859
# ..        ...       ...       ...       ...
# 4    0.149245  0.319579  0.902926  0.291430
# 3     0.07424  0.575926  0.371847  0.447757
# 2    0.271655  0.187802  0.639838  0.211768
# 1    0.264215  0.192503  0.858678  0.960484
# 0     Mabtoor  0.647571  0.655263  0.572103
#
# [443 rows x 4 columns]

# %%
newdf.sort_index(axis=1,ascending=True)
# Out:
#             0         1         2         3
# 0     Mabtoor  0.647571  0.655263  0.572103
# 1    0.264215  0.192503  0.858678  0.960484
# 2    0.271655  0.187802  0.639838  0.211768
# 3     0.07424  0.575926  0.371847  0.447757
# 4    0.149245  0.319579  0.902926  0.291430
# ..        ...       ...       ...       ...
# 438  0.611236  0.868276  0.475830  0.496859
# 439  0.470998  0.714874  0.812492  0.316903
# 440  0.706543  0.318493  0.038463  0.883714
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633
#
# [443 rows x 4 columns]

# %%
newdf2 = newdf

# %%
newdf2
# Out:
#             0         1         2         3
# 0     Mabtoor  0.647571  0.655263  0.572103
# 1    0.264215  0.192503  0.858678  0.960484
# 2    0.271655  0.187802  0.639838  0.211768
# 3     0.07424  0.575926  0.371847  0.447757
# 4    0.149245  0.319579  0.902926  0.291430
# ..        ...       ...       ...       ...
# 438  0.611236  0.868276  0.475830  0.496859
# 439  0.470998  0.714874  0.812492  0.316903
# 440  0.706543  0.318493  0.038463  0.883714
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633
#
# [443 rows x 4 columns]

# %%
newdf2[0][0] = 53
# Out:
# <ipython-input-64-5956218cf162>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[0][0] = 53

# %%
newdf2
# Out:
#             0         1         2         3
# 0          53  0.647571  0.655263  0.572103
# 1    0.264215  0.192503  0.858678  0.960484
# 2    0.271655  0.187802  0.639838  0.211768
# 3     0.07424  0.575926  0.371847  0.447757
# 4    0.149245  0.319579  0.902926  0.291430
# ..        ...       ...       ...       ...
# 438  0.611236  0.868276  0.475830  0.496859
# 439  0.470998  0.714874  0.812492  0.316903
# 440  0.706543  0.318493  0.038463  0.883714
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633
#
# [443 rows x 4 columns]

# %%
newdf
# Out:
#             0         1         2         3
# 0          53  0.647571  0.655263  0.572103
# 1    0.264215  0.192503  0.858678  0.960484
# 2    0.271655  0.187802  0.639838  0.211768
# 3     0.07424  0.575926  0.371847  0.447757
# 4    0.149245  0.319579  0.902926  0.291430
# ..        ...       ...       ...       ...
# 438  0.611236  0.868276  0.475830  0.496859
# 439  0.470998  0.714874  0.812492  0.316903
# 440  0.706543  0.318493  0.038463  0.883714
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633
#
# [443 rows x 4 columns]

# %%
newdf[0][0] = 0.42314
# Out:
# <ipython-input-67-f832aa4d8003>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf[0][0]
# [443 rows x 4 columns]

# %%
newdf.drop(0,axis=1)
# Out:
#             1         2         3
# 0    0.647571  0.655263  0.572103
# 1    0.192503  0.858678  0.960484
# 2    0.187802  0.639838  0.211768
# 3    0.575926  0.371847  0.447757
# 4    0.319579  0.902926  0.291430
# ..        ...       ...       ...
# 438  0.868276  0.475830  0.496859
# 439  0.714874  0.812492  0.316903
# 440  0.318493  0.038463  0.883714
# 441  0.822804  0.357553  0.382375
# 442  0.015466  0.009774  0.085633
#
# [443 rows x 3 columns]

# %%
newdf.iloc[0,2]
# Out:
# 0.6552627779027321

# %%
newdf
# Out:
#             0         1         2         3
# 0    0.532242  0.647571  0.655263  0.572103
# 1    0.264215  0.192503  0.858678  0.960484
# 2    0.271655  0.187802  0.639838  0.211768
# 3     0.07424  0.575926  0.371847  0.447757
# 4    0.149245  0.319579  0.902926  0.291430
# ..        ...       ...       ...       ...
# 438  0.611236  0.868276  0.475830  0.496859
# 439  0.470998  0.714874  0.812492  0.316903
# 440  0.706543  0.318493  0.038463  0.883714
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633
#
# [443 rows x 4 columns]

# %%
newdf.head(2)
# Out:
#           0         1         2         3
# 0  0.532242  0.647571  0.655263  0.572103
# 1  0.264215  0.192503  0.858678  0.960484

# %%
newdf.drop([0])
# Out:
#             0         1         2         3
# 1    0.264215  0.192503  0.858678  0.960484
# 2    0.271655  0.187802  0.639838  0.211768
# 3     0.07424  0.575926  0.371847  0.447757
# 4    0.149245  0.319579  0.902926  0.291430
# 5    0.795054  0.379208  0.013642  0.620365
# ..        ...       ...       ...       ...
# 438  0.611236  0.868276  0.475830  0.496859
# 439  0.470998  0.714874  0.812492  0.316903
# 440  0.706543  0.318493  0.038463  0.883714
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633
#
# [442 rows x 4 columns]

# %%
newdf.drop([1])
# Out:
#             0         1         2         3
# 0    0.532242  0.647571  0.655263  0.572103
# 2    0.271655  0.187802  0.639838  0.211768
# 3     0.07424  0.575926  0.371847  0.447757
# 4    0.149245  0.319579  0.902926  0.291430
# 5    0.795054  0.379208  0.013642  0.620365
# ..        ...       ...       ...       ...
# 438  0.611236  0.868276  0.475830  0.496859
# 439  0.470998  0.714874  0.812492  0.316903
# 440  0.706543  0.318493  0.038463  0.883714
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633
#
# [442 rows x 4 columns]

# %%
newdf.reset_index(drop=True)
# Out:
#             0         1         2         3
# 0    0.532242  0.647571  0.655263  0.572103
# 1    0.264215  0.192503  0.858678  0.960484
# 2    0.271655  0.187802  0.639838  0.211768
# 3     0.07424  0.575926  0.371847  0.447757
# 4    0.149245  0.319579  0.902926  0.291430
# ..        ...       ...       ...       ...
# 438  0.611236  0.868276  0.475830  0.496859
# 439  0.470998  0.714874  0.812492  0.316903
# 440  0.706543  0.318493  0.038463  0.883714
# 441  0.242174  0.822804  0.357553  0.382375
# 442  0.296793  0.015466  0.009774  0.085633
#
# [443 rows x 4 columns]

# %%
newdf.drop([0], axis=1)
# Out:
#             1         2         3
# 0    0.647571  0.655263  0.572103
# 1    0.192503  0.858678  0.960484
# 2    0.187802  0.639838  0.211768
# 3    0.575926  0.371847  0.447757
# 4    0.319579  0.902926  0.291430
# ..        ...       ...       ...
# 438  0.868276  0.475830  0.496859
# 439  0.714874  0.812492  0.316903
# 440  0.318493  0.038463  0.883714
# 441  0.822804  0.357553  0.382375
# 442  0.015466  0.009774  0.085633
#
# [443 rows x 3 columns]

# %%
df.notnull()
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 0       True     True           True    True
# 1       True     True           True    True
# 2       True     True           True    True
# 3       True     True           True    True
# 4       True     True           True    True
# 5       True     True           True    True
# 6       True     True           True    True
# 7       True     True           True    True
# 8       True     True           True    True
# 9       True     True           True    True
# 10      True     True           True    True
# 11      True     True           True    True
# 12      True     True           True    True
# 13      True     True           True    True
# 14      True     True           True    True
# 15      True     True           True    True
# 16      True     True           True    True

# %%
df.max()
# Out:
# train no         23426
# Seat No             87
# Passangers No       87
# ASM NO               8
# dtype: int64

# %%
df.min()
# Out:
# train no         3
# Seat No          2
# Passangers No    2
# ASM NO           1
# dtype: int64

# %%
df.mean()
# Out:
# train no         1941.176471
# Seat No            18.823529
# Passangers No       9.529412
# ASM NO              4.882353
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   train no       17 non-null     int64
#  1   Seat No        17 non-null     int64
#  2   Passangers No  17 non-null     int64
#  3   ASM NO         17 non-null     int64
# dtypes: int64(4)
# memory usage: 672.0 bytes

# %%
df.shape
# Out:
# (17, 4)

# %%
df.isnull()
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 0      False    False          False   False
# 1      False    False          False   False
# 2      False    False          False   False
# 3      False    False          False   False
# 4      False    False          False   False
# 5      False    False          False   False
# 6      False    False          False   False
# 7      False    False          False   False
# 8      False    False          False   False
# 9      False    False          False   False
# 10     False    False          False   False
# 11     False    False          False   False
# 12     False    False          False   False
# 13     False    False          False   False
# 14     False    False          False   False
# 15     False    False          False   False
# 16     False    False          False   False

# %%
df.drop_duplicates(subset=['train no'])
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 0         43        3              6       6
# 1         41        2              3       3
# 3         14        7              5       4
# 4         45        4              7       7
# 5          4        2              3       8
# 6         54        6              6       5
# 7          5        3              8       4
# 8        435       73              4       3
# 9         31        6              2       5
# 12     23426        3              4       3
# 13        44        6              2       6
# 14         3       87              5       8
# 15      5523        4             87       5
# 16      3245       56              4       3

# %%
df.head(2)
# Out:
#    train no  Seat No  Passangers No  ASM NO
# 0        43        3              6       6
# 1        41        2              3       3

# %%
df.tail(2)
# Out:
#     train no  Seat No  Passangers No  ASM NO
# 15      5523        4             87       5
# 16      3245       56              4       3

# %%
df.count()
# Out:
# train no         17
# Seat No          17
# Passangers No    17
# ASM NO           17
# dtype: int64

# %%
df.variance()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-104-f99426934129> in <module>
# ----> 1 df.variance()
#
# D:\Annaconda 3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'variance'

# %%
pd.DataFrame.var(df)
# Out:
# train no         3.287228e+07
# Seat No          7.717794e+02
# Passangers No    4.023897e+02
# ASM NO           3.860294e+00
# dtype: float64

# %%
df.std()
# Out:
# train no         5733.435011
# Seat No            27.780918
# Passangers No      20.059654
# ASM NO              1.964763
# dtype: float64

# %%
df.median()
# Out:
# train no         41.0
# Seat No           6.0
# Passangers No     5.0
# ASM NO            5.0
# dtype: float64

# %%
df.min()
# Out:
# train no         3
# Seat No          2
# Passangers No    2
# ASM NO           1
# dtype: int64

# %%
df.corr()
# Out:
#                train no   Seat No  Passangers No    ASM NO
# train no       1.000000 -0.122264       0.150056 -0.279158
# Seat No       -0.122264  1.000000      -0.155153 -0.137810
# Passangers No  0.150056 -0.155153       1.000000  0.041324
# ASM NO        -0.279158 -0.137810       0.041324  1.000000

# %%
data = pd.read_excel('book.xlsx')

# %%
data
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0          NaN         NaN      train       seat     rollno      marks
# 1          NaN         NaN        434    5454634       5432   50947540
# 2          NaN         NaN        435    5454635       5433   50947541
# 3          NaN         NaN        436    5454636       5434   50947542
# 4          NaN         NaN        437    5454637       5435   50947543
# 5          NaN         NaN        438    5454638       5436   50947544
# 6          NaN         NaN        439    5454639       5437   50947545
# 7          NaN         NaN        440    5454640       5438   50947546
# 8          NaN         NaN        441    5454641       5439   50947547
# 9          NaN         NaN        442    5454642       5440   50947548
# 10         NaN         NaN        443    5454643       5441   50947549
# 11         NaN         NaN        444    5454644       5442   50947550
# ...

# %%
data.head(2)
# Out:
#    Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0         NaN         NaN      train       seat     rollno      marks
# 1         NaN         NaN        434    5454634       5432   50947540

# %%
data.drop([2])
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 3          NaN         NaN        436    5454636       5434   50947542
# 4          NaN         NaN        437    5454637       5435   50947543
# 5          NaN         NaN        438    5454638       5436   50947544
# 6          NaN         NaN        439    5454639       5437   50947545
# 7          NaN         NaN        440    5454640       5438   50947546
# 8          NaN         NaN        441    5454641       5439   50947547
# 9          NaN         NaN        442    5454642       5440   50947548
# 10         NaN         NaN        443    5454643       5441   50947549
# 11         NaN         NaN        444    5454644       5442   50947550
# 12         NaN         NaN        445    5454645       5443   50947551
# 13         NaN         NaN        446    5454646       5444   50947552
# 14         NaN         NaN        447    5454647       5445   50947553
# ...

# %%
data.to_excel('data.xlsx')

# %%
data.dropna(axis=1)
# Out:
#    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 2         435    5454635       5433   50947541
# 3         436    5454636       5434   50947542
# 4         437    5454637       5435   50947543
# 5         438    5454638       5436   50947544
# 6         439    5454639       5437   50947545
# 7         440    5454640       5438   50947546
# 8         441    5454641       5439   50947547
# 9         442    5454642       5440   50947548
# 10        443    5454643       5441   50947549
# 11        444    5454644       5442   50947550
# 12        445    5454645       5443   50947551
# 13        446    5454646       5444   50947552
# 14        447    5454647       5445   50947553
# 15        448    5454648       5446   50947554
# 16        449    5454649       5447   50947555

# %%
data
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 2          NaN         NaN        435    5454635       5433   50947541
# 3          NaN         NaN        436    5454636       5434   50947542
# 4          NaN         NaN        437    5454637       5435   50947543
# 5          NaN         NaN        438    5454638       5436   50947544
# 6          NaN         NaN        439    5454639       5437   50947545
# 7          NaN         NaN        440    5454640       5438   50947546
# 8          NaN         NaN        441    5454641       5439   50947547
# 9          NaN         NaN        442    5454642       5440   50947548
# 10         NaN         NaN        443    5454643       5441   50947549
# 11         NaN         NaN        444    5454644       5442   50947550
# 12         NaN         NaN        445    5454645       5443   50947551
# 13         NaN         NaN        446    5454646       5444   50947552
# ...
